# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
deaths = "AQI CSV Files/covid19_deaths_global.csv"
deaths = pd.read_csv(deaths, delimiter=",")

# %%
reduced_df = deaths.drop(columns=['Lat', "Long"])
reduced_df
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN  Sao Tome and Principe        0        0        0        0
# 262            NaN                  Yemen        0        0        0        0
# 263            NaN                Comoros        0        0        0        0
# 264            NaN             Tajikistan        0        0        0        0
# 265            NaN                Lesotho        0        0        0        0
#
#      1/26/20  1/27/20  1/28/20  1/29/20  ...  7/14/20  7/15/20  7/16/20  \
# 0          0        0        0        0  ...     1048     1094     1113
# 1          0        0        0        0  ...       97      101      104
# 2          0        0        0        0  ...     1028     1040     1052
# 3          0        0        0        0  ...       52       52       52
# 4          0        0        0        0  ...       26       27       28
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 261        0        0        0        0  ...       14       14       14
# 262        0        0        0        0  ...      429      433      438
# 263        0        0        0        0  ...        7        7        7
# 264        0        0        0        0  ...       56       56       56
# 265        0        0        0        0  ...        3        3        3
#
#      7/17/20  7/18/20  7/19/20  7/20/20  7/21/20  7/22/20  7/23/20
# 0       1147     1164     1181     1185     1186     1190     1211
# 1        107      111      112      113      117      120      123
# 2       1057     1068     1078     1087     1100     1111     1124
# 3         52       52       52       52       52       52       52
# 4         29       29       29       29       30       33       33
# ..       ...      ...      ...      ...      ...      ...      ...
# 261       14       14       14       14       14       14       14
# 262      440      443      445      447      456      458      461
# 263        7        7        7        7        7        7        7
# 264       56       57       57       57       57       58       58
# 265        6        6        6        6        6        6        6
#
# [266 rows x 186 columns]

# %%
jan_sum = reduced_df.iloc[:,2:12].sum(axis=1)
feb_sum = reduced_df.iloc[:,12:41].sum(axis=1)
mar_sum = reduced_df.iloc[:,41:72].sum(axis=1)
apr_sum = reduced_df.iloc[:,72:102].sum(axis=1)
may_sum = reduced_df.iloc[:,102:133].sum(axis=1)
jun_sum = reduced_df.iloc[:,133:163].sum(axis=1)
jul_sum = reduced_df.iloc[:,163:186].sum(axis=1)
reduced_df["Jan_sum"] = jan_sum
reduced_df["Feb_sum"] = feb_sum
reduced_df["Mar_sum"] = mar_sum
reduced_df["Apr_sum"] = apr_sum
reduced_df["May_sum"] = may_sum
reduced_df["Jun_sum"] = jun_sum
reduced_df["Jul_sum"] = jul_sum
reduced_df
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN  Sao Tome and Principe        0        0        0        0
# 262            NaN                  Yemen        0        0        0        0
# 263            NaN                Comoros        0        0        0        0
# 264            NaN             Tajikistan        0        0        0        0
# 265            NaN                Lesotho        0        0        0        0
#
#      1/26/20  1/27/20  1/28/20  1/29/20  ...  7/21/20  7/22/20  7/23/20  \
# 0          0        0        0        0  ...     1186     1190     1211
# 1          0        0        0        0  ...      117      120      123
# 2          0        0        0        0  ...     1100     1111     1124
# 3          0        0        0        0  ...       52       52       52
# 4          0        0        0        0  ...       30       33       33
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 261        0        0        0        0  ...       14       14       14
# 262        0        0        0        0  ...      456      458      461
# 263        0        0        0        0  ...        7        7        7
# 264        0        0        0        0  ...       57       58       58
# 265        0        0        0        0  ...        6        6        6
#
#      Jan_sum  Feb_sum  Mar_sum  Apr_sum  May_sum  Jun_sum  Jul_sum
# 0          0        0       29      860     4994    14907    23307
# 1          0        0       91      728      975     1221     2149
# 2          0        0      324     9197    16901    23600    23350
# 3          0        0       39      917     1518     1545     1196
# 4          0        0        6       60       85      210      562
# ..       ...      ...      ...      ...      ...      ...      ...
# 261        0        0        0        0      213      367      314
# 262        0        0        0        2      790     5932     9078
# 263        0        0        0        0       31      117      161
# 264        0        0        0        0      915     1501     1263
# 265        0        0        0        0        0        0       59
#
# [266 rows x 193 columns]

# %%
# reduced_df.iloc[:,2:186]])
totals_df = reduced_df.drop(reduced_df.iloc[:,2:186], axis=1)
totals_df = totals_df.rename(columns={"Province/State":"State","Country/Region":"Country"})
totals_new = totals_df[["Country","State","Jan_sum","Feb_sum","Mar_sum","Apr_sum","May_sum","Jun_sum","Jul_sum"]]
totals_new
# Out:
#                    Country State  Jan_sum  Feb_sum  Mar_sum  Apr_sum  May_sum  \
# 0              Afghanistan   NaN        0        0       29      860     4994
# 1                  Albania   NaN        0        0       91      728      975
# 2                  Algeria   NaN        0        0      324     9197    16901
# 3                  Andorra   NaN        0        0       39      917     1518
# 4                   Angola   NaN        0        0        6       60       85
# ..                     ...   ...      ...      ...      ...      ...      ...
# 261  Sao Tome and Principe   NaN        0        0        0        0      213
# 262                  Yemen   NaN        0        0        0        2      790
# 263                Comoros   NaN        0        0        0        0       31
# 264             Tajikistan   NaN        0        0        0        0      915
# 265                Lesotho   NaN        0        0        0        0        0
#
#      Jun_sum  Jul_sum
# 0      14907    23307
# 1       1221     2149
# 2      23600    23350
# 3       1545     1196
# 4        210      562
# ..       ...      ...
# 261      367      314
# 262     5932     9078
# 263      117      161
# 264     1501     1263
# 265        0       59
#
# [266 rows x 9 columns]

# %%
totals_new.groupby("Country").loc["Afghanistan"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-242-e90520cd8cc3> in <module>
# ----> 1 totals_new.groupby("Country").loc["Afghanistan"]
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'loc'
